# %%
import secrets

import ed25519

# %%
seed_k = secrets.token_bytes(32)

pk = ed25519.pk(seed_k)

# %%
M = "Ana are mere".encode()

sig = ed25519.sign(seed_k, M)
ed25519.verify(pk, M, sig)
# Out:
# True
